# %% [markdown]
# # Tutorial week 8
#
# **a** aaa
#
# ### Question 1 calculations
#
# The rest of the step-by-step is in the .PDF file

# %%
base = 20
exponent = 37
modulus = 60

message = pow(base, exponent, modulus)

print(f"Then, m = {message}")
# Out:
# Then, m = 20

# %% [markdown]
# ### Question 2 calculations
#
# The rest of the step-by-step is in the .PDF file

# %%
base = 65
exponent = -1 # in order to compute the modular inverse of 65 mod 2881
modulus = 2881

d = pow(base, exponent, modulus)

print(f"The private key is d = {d}")
# Out:
# The private key is d = 1507

# %% [markdown]
# ### Question 3
#
# The explanation and logic is in the .PDF file

# %% [markdown]
# ### Question 4 - Code

# %%
from question4_function import isPrime

p1 = 97
p2 = 1000000007
p3 = ...

primes = [p1, p2, p3]

for prime in primes:
    result, prob = isPrime(prime, 30)
    print(f"{prime} is prime: {result} (probability: {prob:.10f})")
# Out:
# 97 is prime: True (probability: 0.9999999991)
# 1000000007 is prime: True (probability: 0.9999999991)
# ... is prime: True (probability: 0.9999999991)
# ... is prime: True (probability: 0.9999999991)

# %% [markdown]
# ### Question 5
